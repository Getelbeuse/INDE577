# %% [markdown]
# # Gradient Descent in Linear and Logistic Regression
#
# Gradient descent is a fundamental optimization algorithm used in machine learning to minimize a cost function. It is particularly useful in training both linear regression and logistic regression models. Here, we delve into how gradient descent is applied in each case.
#
# ## Linear Regression
#
# ### Application Scenario:
# Linear regression is used when the target variable $ y $ is continuous. It is common in predicting house prices, stock prices, temperatures, etc., where the output is a real number.
#
# ### Algorithm:
# In linear regression, the model predicts the output as a linear combination of the input features. The cost function typically used is the Mean Squared Error (MSE), which measures the average of the squares of the errors—that is, the average squared difference between the estimated values and actual value.
#
# ### Mathematical Formulation:
# The model function for linear regression is:
# $$ f(x) = \beta_0 + \beta_1x_1 + \beta_2x_2 + ... + \beta_nx_n $$
# where $ \beta $ represents the coefficients, and $ x $ represents the features.
#
# The MSE cost function is:
# $$ J(\beta) = \frac{1}{2m} \sum_{i=1}^{m} (f(x^{(i)}) - y^{(i)})^2 $$
# where $ m $ is the number of samples, $ x^{(i)} $ are the feature values for the $ i $-th sample, and $ y^{(i)} $ is the actual value for the $ i $-th sample.
#
# #### Gradient Descent Update Rule:
# The parameters $ \beta $ are updated using the formula:
# $$ \beta := \beta - \alpha \frac{\partial J(\beta)}{\partial \beta} $$
# where $ \alpha $ is the learning rate, a tuning parameter in gradient descent that determines the step size at each iteration.
#
# ## Logistic Regression
#
# ### Application Scenario:
# Logistic regression is used for binary classification tasks, such as spam detection, cancer diagnosis, and credit scoring, where the output is categorical.
#
# ### Algorithm:
# Unlike linear regression, logistic regression outputs probabilities using the logistic function, which is a sigmoid function. This ensures that the outputs are between 0 and 1, making them interpretable as probabilities.
#
# ### Mathematical Formulation:
# The model function for logistic regression is:
# $$ p(x) = \frac{1}{1 + e^{-(\beta_0 + \beta_1x_1 + ... + \beta_nx_n)}} $$
# where $ p(x) $ is the probability that the output is 1.
#
# The cost function used is the log-loss, also called binary cross-entropy, defined as:
# $$ J(\beta) = -\frac{1}{m} \sum_{i=1}^{m} [y^{(i)} \log(p(x^{(i)})) + (1 - y^{(i)}) \log(1 - p(x^{(i)}))] $$
#
# #### Gradient Descent Update Rule:
# The update rule for logistic regression is similar to that of linear regression, using the partial derivatives of the log-loss:
# $$ \beta := \beta - \alpha \frac{\partial J(\beta)}{\partial \beta} $$
#
# ### Conclusion
# In both linear and logistic regression, gradient descent serves to find the set of coefficients $ \beta $ that minimize the cost function. The specific form of the cost function and the model output differ, aligning with the needs of predicting continuous outputs in linear regression and probabilities in logistic regression.
# sion and probabilities in logistic regression.

# %% [markdown]
# ## A little bit about Linear Regression.
#
# The main quality of a linear regression problem is that there is a roughly linear relationship between the input data, ${x_1,x_2...x_n}$, and the output data, ${y_1,y_2...y_n}$. This relationship between the independent and dependent variables is important to have in order for linear regression to accurately model the relationship. The goal for linear regression is to find the best line of fit that minimizes a certain cost function that contains the differences between the expected and actual values of the dependent variable (we want to minimize this error).
#
# As opposed to the perceptron, linear regression is used to predict continuous values, while the perceptron predicts discrete binary values. In order for linear regression to determine a boundary line, it uses a linear activation function, like the perceptron. As denoted by the picture below, the linear activation function takes the linear combination of all the inputs and each of its corresponding weights, and it ouputs a single value, z. The weights and bias terms are minimized during the training process and the differences are minimized. The output, z, is the predicted value of the dependent variable. So, the linear activation function will look like this: $z= b + w_1x_1 + w_2x_2 +...+w_nx_n$.
#
# ![Image Alt Text](regression_neuron.png)
#
#
# (diagram credit to Dr. Davila :)
#
# Additionally, you can see that a cost function must be defined as well in order to train the model. Typically, we use the MSE (mean-squared error) for basic linear regresion cases like these, but other cost functions like MAE (mean absolute error) can also be used. MSE takes each predicted - actual difference value and squares it, adds those squared differences together, and divides them across the number of inputs to get an average of these squared differences across the dataset. The training process aims to minimize the value of the MSE function.

# %% [markdown]
# ## A little bit about Gradient Descent.
#
# In order to minimize the MSE function, we use gradient descent! This optimization algorithm aims to find a local minimum of a differentiable function. It starts with an initial guess, an initial set of weights and bias, and updates the next iteration to be a little closer to the minima. It does this by using a step length hyperparameter, which determines how far of a step the algorithm should take for the next iteration. Gradient descent moves in the direction opposite to the sign of the derivative. As the model trains, the weights and biases are repeatedly updated to reflect the cost function reaching a minimum. Once it reaches the minimum, the trained model can then be used to make predictions on new data!
#
# Batch gradient descent and stochastic gradient descent can both be used to train models. Batch gradient descent will calculate the entire gradient for every epoch over the entire training set. This results in a very slow and computationally expensive algorithm. Conversely, stochastic gradient descent picks an instance of the training data at each epoch and then computes the gradient there. This is much faster, as there is less data to manipulate. For our single neuron model, this is the preferred method.
#
#
# ![gradient descent](gradient_descent.jpg)

# %% [markdown]
# # Application
#
# In this module, we will implement linear regression on the Gentoo Penguins portion of the Palmer Penguins dataset. We will be attempting to predict the bill depth of a Gentoo penguin, given the bill length
#
# Provided here is the SingleNeuron class that implements all of the math and logic into code.

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
from mlxtend.plotting import plot_decision_regions

class SingleNeuron(object):
    """
    A class used to represent a single artificial neuron. 

    ...

    Attributes
    ----------
    activation_function : function
        The activation function applied to the preactivation linear combination.
    
    cost_function : function
        The cost function used to measure model performance.

    w_ : numpy.ndarray
        The weights and bias of the single neuron. The last entry being the bias. 
        This attribute is created when the train method is called.

    errors_: list
        A list containing the mean sqaured error computed after each iteration 
        of stochastic gradient descent per epoch. 

    Methods
    -------
    train(self, X, y, alpha = 0.005, epochs = 50)
        Iterates the stochastic gradient descent algorithm through each sample 
        a total of epochs number of times with learning rate alpha. The data 
        used consists of feature vectors X and associated labels y. 

    predict(self, X)
        Uses the weights and bias, the feature vectors in X, and the 
        activation_function to make a y_hat prediction on each feature vector. 
    """
    def __init__(self, activation_function, cost_function):
        self.activation_function = activation_function
        self.cost_function = cost_function

    def train(self, X, y, alpha = 0.005, epochs = 50):
   
        self.w_ = np.random.rand(1 + X.shape[1])
        self.errors_ = []
        N = X.shape[0]

        for _ in range(epochs):
            errors = 0
            for xi, target in zip(X, y):
                error = (self.predict(xi) - target)
                self.w_[:-1] -= alpha*error*xi
                self.w_[-1] -= alpha*error
                #errors += .5*((self.predict(xi) - target)**2)
                errors += self.cost_function(self.predict(xi), target)
            self.errors_.append(errors/N)
        return self

    def predict(self, X):
        preactivation = np.dot(X, self.w_[:-1]) + self.w_[-1]
        return self.activation_function(preactivation)

    def plot_cost_function(self):
        fig, axs = plt.subplots(figsize = (10, 8))
        axs.plot(range(1, len(self.errors_) + 1), 
                self.errors_,
                label = "Cost function")
        axs.set_xlabel("epochs", fontsize = 15)
        axs.set_ylabel("Cost", fontsize = 15)
        axs.legend(fontsize = 15)
        axs.set_title("Cost Calculated after Epoch During Training", fontsize = 18)
        plt.show()

    def plot_decision_boundary(self, X, y, xstring="x", ystring="y"):
        plt.figure(figsize = (10, 8))
        plot_decision_regions(X, y, clf = self)
        plt.title("Neuron Decision Boundary", fontsize = 18)
        plt.xlabel(xstring, fontsize = 15)
        plt.ylabel(ystring, fontsize = 15)
        plt.show()

# %% [markdown]
# We import all of our necessary modules and set our display theme to seaborn (because it looks nicer).

# %%
import seaborn as sns
sns.set_theme()

#We a) load in the datab) narrow it down to only the relevant rows, c) drop NaN values, and d) check out the first few entries
df = pd.read_csv(r"/Users/betelgeuse/INDE577-main/577repo/Supervised Learning/Datasets/palmer_penguins.csv")
df = df.iloc[220:]
df = df.dropna()

df.head()
# Out:
#      Unnamed: 0 species  island  bill_length_mm  bill_depth_mm  \
# 220         220  Gentoo  Biscoe            46.1           13.2
# 221         221  Gentoo  Biscoe            50.0           16.3
# 222         222  Gentoo  Biscoe            48.7           14.1
# 223         223  Gentoo  Biscoe            50.0           15.2
# 224         224  Gentoo  Biscoe            47.6           14.5
#
#      flipper_length_mm  body_mass_g     sex
# 220              211.0       4500.0  Female
# 221              230.0       5700.0    Male
# 222              210.0       4450.0  Female
# 223              218.0       5700.0    Male
# 224              215.0       5400.0    Male

# %% [markdown]
# Next, we plot the data to see if we can approximate a roughly linear relationship between bill length and bill depth- i.e. we check if linear regression is even an appropriate model to use here.

# %%
plt.figure(figsize = (10, 7))
plt.scatter(df.bill_length_mm, 
            df.bill_depth_mm, 
            color = "red",
            label = "Gentoo Penguins")
plt.xlabel("bill length (mm)", fontsize = 15)
plt.ylabel("bill depth (mm)", fontsize = 15)
plt.legend(fontsize = 15)
plt.title("Regression Data on Gentoo Penguins", fontsize = 18)
plt.show()

# %% [markdown]
# Fortunately, it exists- you can definitely draw a potential line here! We are now going to convert the data into a numpy.ndarray and extract out the relevant columns.

# %%
X = df['bill_length_mm'].values.reshape(-1, 1)
y = df['bill_depth_mm'].values

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %% [markdown]
# We train the model!

# %%
def linear_activation(z):
    return z

def mse(y_true, y_pred):
    """
    Calculate the mean squared error between the true labels and predicted labels.
    
    Parameters:
    y_true (numpy.array): Array of true labels.
    y_pred (numpy.array): Array of predicted labels.
    
    Returns:
    float: Mean squared error.
    """
    return np.mean((y_true - y_pred) ** 2)



model = SingleNeuron(linear_activation, mse)
model.train(X, y, alpha = 0.0008, epochs = 1000)

y_pred = model.predict(X_test)

plt.figure(figsize = (10, 8))
plt.scatter(X, y, color = "blue", label = "gentoo penguins")
plt.plot(X, model.predict(X.reshape(-1, 1)))
plt.xlabel("bill length [mm]", fontsize = 15)
plt.ylabel("bill width [mm]", fontsize = 15)
plt.title("Gentoo Regression Data", fontsize = 18)
plt.legend(fontsize = 15)
plt.show()

# %% [markdown]
# The line is super misaligned- this means our step size is too large! Let's make it smaller to improve the accuracy.

# %%
model = SingleNeuron(linear_activation, mse)
model.train(X, y, alpha = 0.0001, epochs = 1000) #so alpha is a lot smaller here

y_pred = model.predict(X_test)

plt.figure(figsize = (10, 8))
plt.scatter(X, y, color = "blue", label = "gentoo penguins")
plt.plot(X, model.predict(X.reshape(-1, 1)))
plt.xlabel("bill length [mm]", fontsize = 15)
plt.ylabel("bill width [mm]", fontsize = 15)
plt.title("Gentoo Regression Data", fontsize = 18)
plt.legend(fontsize = 15)
plt.show()

# %% [markdown]
# Check out the errors and accuracy.

# %%
error = mse(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print("Mean Squared Error:", error)
print("R^2 Score:", r2)
# Out:
# Mean Squared Error: 0.6304609270913543
# R^2 Score: 0.44888515266500195

# %% [markdown]
# We graph the MSE of the model.

# %%
plt.figure(figsize = (10, 8))
plt.plot(range(1, len(model.errors_) + 1), 
         model.errors_,
         marker = "o",
         label = "MSE")
plt.xlabel("epochs", fontsize = 15)
plt.ylabel("MSE", fontsize = 15)
plt.xticks(range(1, len(model.errors_) + 1))
plt.legend(fontsize = 15)
plt.title("MSE Error at Each Epoch During Training", fontsize = 18)
plt.show()

# %% [markdown]
# Yay! We have now learned two important single neuron models. Next, we move onto more complex models.
